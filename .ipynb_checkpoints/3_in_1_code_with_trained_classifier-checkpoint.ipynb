# %% [markdown]
# # 3 in one code, with trained classifier.
# ### INPUT:
#     - images folder path (... .png)
#     - masks foler path (..._mask.png)
#
#     - path for the output file .csv with results of all 3 featues and the probability of a lesion to be melanoma
# ### OUTPUT:
#     - .csv with results of all 3 featues and the probability of a lesion to be melanoma
#
# #### Output understanding:
# ##### image_path
# ##### color_score
#               ( 1 - relatively dull or monochromatic,
#                 2 - some color variation, but it may lack intensity or diversity,
#                 3 - significant color variation with vibrant and diverse hues,
#                 4 - intense and varied colors, resembling a rainbow )
#
# ##### symmetry_score
#                ( 1 - none symmetry
#                  2 - low symmetry
#                  3 - moderate symmetry
#                  4 - perfect symmetry )
# ##### blue_white_score
#                  ( 0 - blue-white veil not detected,
#                    1 - blue-white veil detected)
#
# ##### probability_0
#     [0;1] confidance that the lesion belongs to class 0 (non melanoma)
# ##### probability_1
#     [0;1] confidance that the lesion belongs to class 1 (melanoma)
#
# Example, if probability_0 is 0.7 and probability_1 is 0.3 for a particular image-mask pair, it means that the classifier is 70% confident that the pair belongs to class 0 and 30% confident that it belongs to class 1.
#
#
#
# The classifier is: "trained_random_forest_classifier.pkl" on the main page of the repository.
# Please input the paths with " / " not " \ "
#
#
# #### example of inputs:
#      - image_folder = "C:/Users/cieci/OneDrive/Dokumenty/GitHub/G/images_orginal"
#      - mask_folder = "C:/Users/cieci/OneDrive/Dokumenty/GitHub/G/masks_orginal"
#      - output_csv = "C:/Users/cieci/OneDrive/Dokumenty/GitHub/G/results.csv"

# %%
from PIL import Image
import cv2
import numpy as np
import csv
import os
import joblib  


def calculate_color_score(image_path, mask_path):
    #load the image and its corresponding mask
    image = Image.open(image_path)
    mask = Image.open(mask_path).convert('L')

    #PIL image to numpy array
    rgb_img = np.array(image)
    mask = np.array(mask)

    #find coordinates of the lesion in the mask
    lesion_coords = np.where(mask != 0)
    min_x = min(lesion_coords[0])
    max_x = max(lesion_coords[0])
    min_y = min(lesion_coords[1])
    max_y = max(lesion_coords[1])
    cropped_lesion = rgb_img[min_x:max_x, min_y:max_y]

    #calculate the variance of colors
    color_variance = np.var(cropped_lesion, axis=(0, 1))

    #colorfulness score 
    colorfulness_score = np.sum(color_variance)

    #colorfulness score
    if colorfulness_score > 10000:
        color_score = 4
    elif colorfulness_score > 5000:
        color_score = 3
    elif colorfulness_score > 1000:
        color_score = 2
    else:
        color_score = 1

    return color_score


def calculate_symmetry_score(mask_image):
    def double_black_background(input_image):
        #convert the input image to grayscale if it's not already
        if len(input_image.shape) > 2:
            input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)

        #get the size of the original image
        height, width = input_image.shape[:2]

        #create a new image with double black background (so during the roatation the lesion won't be outside the borded of image)
        new_img = np.zeros((height * 2, width * 2), dtype=np.uint8)

        #put the original image in the center of the new image
        offset_x = (width // 2)
        offset_y = (height // 2)
        new_img[offset_y:offset_y+height, offset_x:offset_x+width] = input_image

        return new_img

    def find_longest_diameter(mask_image):
        #find the longest diameter of the lesion in the mask
        contours, _ = cv2.findContours(mask_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contour = max(contours, key=cv2.contourArea)
        rect = cv2.minAreaRect(contour)
        return rect



    def rotate_image(image, angle):
        #get the dimensions of the image
        h, w = image.shape[:2]

        #rotation matrix
        rotation_matrix = cv2.getRotationMatrix2D((w/2, h/2), angle, 1)

        #rotation
        rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

        return rotated_image

    def crop_to_sides(mask_image, rect):
        #angle of rotation
        angle = rect[2]
       
        if angle > 90:
            angle -= 180

        #rotate the mask image
        rotated_mask = rotate_image(mask_image, angle)

        #find contours of the rotated lesion
        contours, _ = cv2.findContours(rotated_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        #find the bounding rectangle of the rotated lesion
        x, y, w, h = cv2.boundingRect(contours[0])

        #crop the rotated mask image to include the left and right sides of the lesion
        cropped_mask = rotated_mask[y:y+h, x:x+w]

        return cropped_mask


    def calculate_pixel_differences(mask_image):

        #total number of pixels in the mask image
        total_pixels = mask_image.size

        #calculate the center of the mask
        center_x = mask_image.shape[1] // 2
        center_y = mask_image.shape[0] // 2

        #split the mask into left and right halves
        left_half = mask_image[:, :center_x]
        right_half = mask_image[:, center_x:]

        #calculate the pixel count differences on each half vertically
        left_pixel_count_vertical = cv2.countNonZero(left_half)
        right_pixel_count_vertical = cv2.countNonZero(right_half)
        vertical_difference = abs(left_pixel_count_vertical - right_pixel_count_vertical)

        #split the mask into top and bottom halves
        top_half = mask_image[:center_y, :]
        bottom_half = mask_image[center_y:, :]

        #pixel count differences on each half horizontally
        top_pixel_count_horizontal = cv2.countNonZero(top_half)
        bottom_pixel_count_horizontal = cv2.countNonZero(bottom_half)
        horizontal_difference = abs(top_pixel_count_horizontal - bottom_pixel_count_horizontal)

        #fraction of similarity vertically
        vertical_similarity = 1 - (vertical_difference / total_pixels)

        #fraction of similarity horizontally
        horizontal_similarity = 1 - (horizontal_difference / total_pixels)

        return vertical_similarity, horizontal_similarity

    def calculate_similarity_score(vertical_similarity, horizontal_similarity):
        if vertical_similarity > 0.95 and horizontal_similarity > 0.95:
            return 4
        elif vertical_similarity > 0.91 and horizontal_similarity > 0.91:
            return 3
        elif vertical_similarity > 0.8 and horizontal_similarity > 0.8:
            return 2
        else:
            return 1

    
    masked_image = double_black_background(mask_image)
    longest_diameter = find_longest_diameter(masked_image)
    cropped_mask = crop_to_sides(masked_image, longest_diameter)
    vertical_similarity, horizontal_similarity = calculate_pixel_differences(cropped_mask)
    similarity_score = calculate_similarity_score(vertical_similarity, horizontal_similarity)
    return similarity_score


def calculate_blue_white_score(image_path, mask_path):

    #load the image and mask
    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    #resize the mask to match the dimensions of the image
    if image.shape[:2] != mask.shape[:2]:
        print("Image and mask dimensions do not match. Resizing mask...")
        mask = cv2.resize(mask, (image.shape[1], image.shape[0]))

    #convert image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    #define broader range for blue colors in HSV
    lower_blue = np.array([100, 50, 50])  
    upper_blue = np.array([140, 255, 255])  

    #define a range for detecting white /very light colors
    lower_white = np.array([0, 0, 200])  
    upper_white = np.array([180, 25, 255])  

    #create a mask for blue and white colors
    blue_mask = cv2.inRange(hsv_image, lower_blue, upper_blue)
    white_mask = cv2.inRange(hsv_image, lower_white, upper_white)
    
    if cv2.countNonZero(blue_mask)==0:
        return 0 
        #problem with just dry skin on the image (so if blue is empty, dont look at the white)
    else:
        #combine the blue and white masks
        combined_color_mask = cv2.bitwise_or(blue_mask, white_mask)

        #combine the color mask with the original lesion mask
        combined_mask = cv2.bitwise_and(mask, mask, mask=combined_color_mask)

        #area of blue-white veil
        blue_white_area = cv2.countNonZero(combined_mask)

        #area of the lesion (non-zero pixels in the mask)
        lesion_area = cv2.countNonZero(mask)

        #ratio of blue-white veil area to lesion area
        ratio = blue_white_area / lesion_area

        if ratio > 0.1:
            return 1
        else:
            return 0


def calculate_probabilities(features, classifier):
    probabilities = classifier.predict_proba([features])
    return probabilities[0]


def calculate_features(image_path, mask_path):
    
    color_score = calculate_color_score(image_path, mask_path)

   
    mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    
    symmetry_score = calculate_symmetry_score(mask_image)

    
    blue_white_score = calculate_blue_white_score(image_path, mask_path)

    return color_score, symmetry_score, blue_white_score


def process_images(image_folder, mask_folder, output_csv, classifier):
    results = []

    #iterate over files in the image folder
    for image_filename in os.listdir(image_folder):
        if image_filename.endswith(".png"):  # Check if the file is a PNG image
            image_path = os.path.join(image_folder, image_filename)
            mask_filename = image_filename.split('.')[0] + '_mask.png'  #mask filenames follow this pattern
            mask_path = os.path.join(mask_folder, mask_filename)

            try:
                print(f"Processing image: {image_path}, mask: {mask_path}")

                #calculate features
                features = calculate_features(image_path, mask_path)

                #calculate probabilities
                probabilities = calculate_probabilities(features, classifier)

                results.append({
                    'image_path': image_filename,
                    'color_score': features[0],
                    'symmetry_score': features[1],
                    'blue_white_score': features[2],
                    'probability_0': probabilities[0],  #probability for class 0
                    'probability_1': probabilities[1]   #probability for class 1
                })
            except FileNotFoundError:
                print(f"File not found: {image_filename}. Skipping...")

    #write results to CSV
    write_results_to_csv(results, output_csv)


def write_results_to_csv(results, output_csv):
    fieldnames = ['image_path', 'color_score', 'symmetry_score', 'blue_white_score', 'probability_0', 'probability_1']

    with open(output_csv, mode='w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for result in results:
            writer.writerow(result)


if __name__ == "__main__":
    #load the trained classifier
    classifier = joblib.load("C:/Users/cieci/OneDrive/Dokumenty/GitHub/G/trained_random_forest_classifier.pkl")

    image_folder = input("Enter the folder containing images: ")
    mask_folder = input("Enter the folder containing masks: ")
    output_csv = input("Enter the path for the output CSV file: ")

    #process images
    process_images(image_folder, mask_folder, output_csv, classifier)
    print("done:)")
# Out:
# Enter the folder containing images: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal
# Enter the folder containing masks: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal
# Enter the path for the output CSV file: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\result.csv
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1020_111_593.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1020_111_593_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1022_115_132.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1022_115_132_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1067_284_533.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1067_284_533_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_108_424_944.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_108_424_944_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1130_501_181.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1130_501_181_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_122_185_957.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_122_185_957_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1249_862_658.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1249_862_658_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1252_866_852.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1252_866_852_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_126_191_304.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_126_191_304_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1322_1137_201.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1322_1137_201_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1365_1253_912.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1365_1253_912_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1370_1274_515.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1370_1274_515_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1388_3513_146.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1388_3513_146_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_138_205_296.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_138_205_296_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1392_1352_778.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1392_1352_778_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1404_1393_540.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1404_1393_540_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1406_1397_669.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1406_1397_669_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1414_1431_754.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1414_1431_754_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1415_1439_295.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1415_1439_295_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1439_1522_211.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1439_1522_211_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1506_1735_733.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1506_1735_733_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1521_1778_763.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1521_1778_763_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_152_230_934.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_152_230_934_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1531_1800_683.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1531_1800_683_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_153_233_45.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_153_233_45_mask.png
# File not found: PAT_153_233_45.png. Skipping...
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1547_4232_115.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1547_4232_115_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_154_235_162.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_154_235_162_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_154_237_625.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_154_237_625_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1572_2495_335.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1572_2495_335_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1586_2624_615.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1586_2624_615_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1608_2720_196.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1608_2720_196_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1618_2771_628.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1618_2771_628_mask.png
# File not found: PAT_1618_2771_628.png. Skipping...
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1641_2886_284.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1641_2886_284_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1689_3075_38.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1689_3075_38_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1690_3082_117.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1690_3082_117_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_16_24_691.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_16_24_691_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1707_3148_835.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1707_3148_835_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1708_3153_799.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1708_3153_799_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1709_3159_144.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1709_3159_144_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1735_3242_27.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1735_3242_27_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1736_3246_166.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1736_3246_166_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1770_3344_274.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1770_3344_274_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1805_3477_772.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1805_3477_772_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_181_832_158.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_181_832_158_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_184_284_721.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_184_284_721_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_198_302_44.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_198_302_44_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_198_853_778.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_198_853_778_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_1993_4077_139.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_1993_4077_139_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_2011_4141_862.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_2011_4141_862_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_2103_4581_72.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_2103_4581_72_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_2144_4738_120.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_2144_4738_120_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_224_1340_142.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_224_1340_142_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_246_377_159.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_246_377_159_mask.png
# File not found: PAT_246_377_159.png. Skipping...
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_253_384_607.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_253_384_607_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_311_666_191.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_311_666_191_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_330_695_90.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_330_695_90_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_338_709_306.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_338_709_306_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_340_714_314.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_340_714_314_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_354_1814_619.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_354_1814_619_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_356_4511_960.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_356_4511_960_mask.png
# File not found: PAT_356_4511_960.png. Skipping...
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_362_744_283.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_362_744_283_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_386_1554_362.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_386_1554_362_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_403_804_994.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_403_804_994_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_407_810_390.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_407_810_390_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_463_897_440.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_463_897_440_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_464_899_646.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_464_899_646_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_465_901_106.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_465_901_106_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_492_1784_50.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_492_1784_50_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_492_4723_890.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_492_4723_890_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_50_76_296.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_50_76_296_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_522_986_800.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_522_986_800_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_526_3205_611.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_526_3205_611_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_528_992_124.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_528_992_124_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_535_1011_567.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_535_1011_567_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_53_1370_288.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_53_1370_288_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_549_1043_36.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_549_1043_36_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_557_1058_309.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_557_1058_309_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_558_1072_486.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_558_1072_486_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_595_1142_142.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_595_1142_142_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_600_1141_988.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_600_1141_988_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_601_1147_943.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_601_1147_943_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_621_3591_171.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_621_3591_171_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_624_1180_803.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_624_1180_803_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_63_99_189.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_63_99_189_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_63_99_736.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_63_99_736_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_640_1210_293.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_640_1210_293_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_641_1211_321.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_641_1211_321_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_649_1233_229.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_649_1233_229_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_664_1263_781.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_664_1263_781_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_677_1349_851.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_677_1349_851_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_67_104_730.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_67_104_730_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_683_1296_237.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_683_1296_237_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_68_105_871.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_68_105_871_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_690_1309_217.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_690_1309_217_mask.png
# Processing image: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\images_orginal\PAT_691_1311_2.png, mask: C:\Users\cieci\OneDrive\Dokumenty\GitHub\GroupIT-working-on-project\data\masks_orginal\PAT_691_1311_2_mask.png
